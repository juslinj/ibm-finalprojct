# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

#-------  For centering figures 
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>.container { width:95% !important; }</style>
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
# !pip install matplotlib
# !pip install plotly
# !pip install pandas dash
# !pip install sklearn
# !pip install pandas
# !pip install fairlearn
# !pip install bokeh
# !pip install matplotlib
# !pip install plotly
# !pip uninstall werkzeug  --y
# !pip install werkzeug==2.0.1
# !pip uninstall dash --y
# !pip install dash
# !pip install pandas dash
# !pip install jupyter-dash
# !pip install Flask==2.1.0
# !pip install environ
# Out:
# Requirement already satisfied: matplotlib in c:\users\jusli\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\jusli\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: plotly in c:\users\jusli\anaconda3\lib\site-packages (5.22.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jusli\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in c:\users\jusli\anaconda3\lib\site-packages (from plotly) (23.2)
# Requirement already satisfied: pandas in c:\users\jusli\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: dash in c:\users\jusli\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jusli\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jusli\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jusli\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jusli\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.1.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (3.0.4)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (5.22.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\jusli\anaconda3\lib\site-packages (from dash) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (4.11.0)
# Requirement already satisfied: requests in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.32.2)
# Requirement already satisfied: retrying in c:\users\jusli\anaconda3\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\jusli\anaconda3\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\jusli\anaconda3\lib\site-packages (from dash) (69.5.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jusli\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.2.2)
# Requirement already satisfied: packaging in c:\users\jusli\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\jusli\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\jusli\anaconda3\lib\site-packages (from Werkzeug<3.1->dash) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\jusli\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jusli\anaconda3\lib\site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jusli\anaconda3\lib\site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jusli\anaconda3\lib\site-packages (from requests->dash) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jusli\anaconda3\lib\site-packages (from requests->dash) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\jusli\anaconda3\lib\site-packages (from click>=8.0->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [15 lines of output]
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# Encountered error while generating package metadata.
#
# See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Requirement already satisfied: pandas in c:\users\jusli\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jusli\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jusli\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jusli\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jusli\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\jusli\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting fairlearn
#   Downloading fairlearn-0.10.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.24.4 in c:\users\jusli\anaconda3\lib\site-packages (from fairlearn) (1.26.4)
# Requirement already satisfied: pandas>=2.0.3 in c:\users\jusli\anaconda3\lib\site-packages (from fairlearn) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.2.1 in c:\users\jusli\anaconda3\lib\site-packages (from fairlearn) (1.4.2)
# Requirement already satisfied: scipy>=1.9.3 in c:\users\jusli\anaconda3\lib\site-packages (from fairlearn) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jusli\anaconda3\lib\site-packages (from pandas>=2.0.3->fairlearn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jusli\anaconda3\lib\site-packages (from pandas>=2.0.3->fairlearn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jusli\anaconda3\lib\site-packages (from pandas>=2.0.3->fairlearn) (2023.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\jusli\anaconda3\lib\site-packages (from scikit-learn>=1.2.1->fairlearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from scikit-learn>=1.2.1->fairlearn) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\jusli\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.3->fairlearn) (1.16.0)
# Downloading fairlearn-0.10.0-py3-none-any.whl (234 kB)
#    ---------------------------------------- 0.0/234.1 kB ? eta -:--:--
#    - -------------------------------------- 10.2/234.1 kB ? eta -:--:--
#    - -------------------------------------- 10.2/234.1 kB ? eta -:--:--
#    --- ----------------------------------- 20.5/234.1 kB 131.3 kB/s eta 0:00:02
#    ------ -------------------------------- 41.0/234.1 kB 245.8 kB/s eta 0:00:01
#    ----------- --------------------------- 71.7/234.1 kB 328.6 kB/s eta 0:00:01
#    ----------------------------- -------- 184.3/234.1 kB 696.3 kB/s eta 0:00:01
#    -------------------------------------- 234.1/234.1 kB 753.7 kB/s eta 0:00:00
# Installing collected packages: fairlearn
# Successfully installed fairlearn-0.10.0
# Requirement already satisfied: bokeh in c:\users\jusli\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\jusli\anaconda3\lib\site-packages (from bokeh) (3.1.4)
# Requirement already satisfied: contourpy>=1.2 in c:\users\jusli\anaconda3\lib\site-packages (from bokeh) (1.2.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\jusli\anaconda3\lib\site-packages (from bokeh) (1.26.4)
# Requirement already satisfied: packaging>=16.8 in c:\users\jusli\anaconda3\lib\site-packages (from bokeh) (23.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\jusli\anaconda3\lib\site-packages (from bokeh) (2.2.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\jusli\anaconda3\lib\site-packages (from bokeh) (10.3.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\jusli\anaconda3\lib\site-packages (from bokeh) (6.0.1)
# Requirement already satisfied: tornado>=6.2 in c:\users\jusli\anaconda3\lib\site-packages (from bokeh) (6.4.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\jusli\anaconda3\lib\site-packages (from bokeh) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jusli\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jusli\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jusli\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jusli\anaconda3\lib\site-packages (from pandas>=1.2->bokeh) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\jusli\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\jusli\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jusli\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\jusli\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: plotly in c:\users\jusli\anaconda3\lib\site-packages (5.22.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jusli\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in c:\users\jusli\anaconda3\lib\site-packages (from plotly) (23.2)
# Found existing installation: Werkzeug 3.0.4
# Uninstalling Werkzeug-3.0.4:
#   Successfully uninstalled Werkzeug-3.0.4
# Collecting werkzeug==2.0.1
#   Using cached Werkzeug-2.0.1-py3-none-any.whl.metadata (4.4 kB)
# Using cached Werkzeug-2.0.1-py3-none-any.whl (288 kB)
# Installing collected packages: werkzeug
# Successfully installed werkzeug-2.0.1
# Found existing installation: dash 2.18.0
# Uninstalling dash-2.18.0:
#   Successfully uninstalled dash-2.18.0
# Collecting dash
#   Using cached dash-2.18.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.1.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.0.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (5.22.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\jusli\anaconda3\lib\site-packages (from dash) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (4.11.0)
# Requirement already satisfied: requests in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.32.2)
# Requirement already satisfied: retrying in c:\users\jusli\anaconda3\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\jusli\anaconda3\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\jusli\anaconda3\lib\site-packages (from dash) (69.5.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jusli\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.2.2)
# Requirement already satisfied: packaging in c:\users\jusli\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (23.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\jusli\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jusli\anaconda3\lib\site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jusli\anaconda3\lib\site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jusli\anaconda3\lib\site-packages (from requests->dash) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jusli\anaconda3\lib\site-packages (from requests->dash) (2024.7.4)
# Requirement already satisfied: six>=1.7.0 in c:\users\jusli\anaconda3\lib\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: colorama in c:\users\jusli\anaconda3\lib\site-packages (from click>=8.0->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jusli\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask<3.1,>=1.0.4->dash) (2.1.3)
# Using cached dash-2.18.0-py3-none-any.whl (7.5 MB)
# Installing collected packages: dash
# Successfully installed dash-2.18.0
# Requirement already satisfied: pandas in c:\users\jusli\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: dash in c:\users\jusli\anaconda3\lib\site-packages (2.18.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jusli\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jusli\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jusli\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jusli\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.1.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.0.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (5.22.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\jusli\anaconda3\lib\site-packages (from dash) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\jusli\anaconda3\lib\site-packages (from dash) (4.11.0)
# Requirement already satisfied: requests in c:\users\jusli\anaconda3\lib\site-packages (from dash) (2.32.2)
# Requirement already satisfied: retrying in c:\users\jusli\anaconda3\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\jusli\anaconda3\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\jusli\anaconda3\lib\site-packages (from dash) (69.5.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jusli\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.2.2)
# Requirement already satisfied: packaging in c:\users\jusli\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\jusli\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\jusli\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jusli\anaconda3\lib\site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jusli\anaconda3\lib\site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jusli\anaconda3\lib\site-packages (from requests->dash) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jusli\anaconda3\lib\site-packages (from requests->dash) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\jusli\anaconda3\lib\site-packages (from click>=8.0->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jusli\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask<3.1,>=1.0.4->dash) (2.1.3)
# Requirement already satisfied: jupyter-dash in c:\users\jusli\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: dash in c:\users\jusli\anaconda3\lib\site-packages (from jupyter-dash) (2.18.0)
# Requirement already satisfied: requests in c:\users\jusli\anaconda3\lib\site-packages (from jupyter-dash) (2.32.2)
# Requirement already satisfied: flask in c:\users\jusli\anaconda3\lib\site-packages (from jupyter-dash) (2.1.0)
# Requirement already satisfied: retrying in c:\users\jusli\anaconda3\lib\site-packages (from jupyter-dash) (1.3.4)
# Requirement already satisfied: ipython in c:\users\jusli\anaconda3\lib\site-packages (from jupyter-dash) (8.25.0)
# Requirement already satisfied: ipykernel in c:\users\jusli\anaconda3\lib\site-packages (from jupyter-dash) (6.28.0)
# Requirement already satisfied: ansi2html in c:\users\jusli\anaconda3\lib\site-packages (from jupyter-dash) (1.9.2)
# Requirement already satisfied: nest-asyncio in c:\users\jusli\anaconda3\lib\site-packages (from jupyter-dash) (1.6.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\jusli\anaconda3\lib\site-packages (from dash->jupyter-dash) (2.0.1)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash->jupyter-dash) (5.22.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash->jupyter-dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\jusli\anaconda3\lib\site-packages (from dash->jupyter-dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\jusli\anaconda3\lib\site-packages (from dash->jupyter-dash) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\jusli\anaconda3\lib\site-packages (from dash->jupyter-dash) (4.11.0)
# Requirement already satisfied: setuptools in c:\users\jusli\anaconda3\lib\site-packages (from dash->jupyter-dash) (69.5.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\jusli\anaconda3\lib\site-packages (from flask->jupyter-dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\jusli\anaconda3\lib\site-packages (from flask->jupyter-dash) (2.2.0)
# Requirement already satisfied: click>=8.0 in c:\users\jusli\anaconda3\lib\site-packages (from flask->jupyter-dash) (8.1.7)
# Requirement already satisfied: comm>=0.1.1 in c:\users\jusli\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\jusli\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\jusli\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\jusli\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\jusli\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (0.1.6)
# Requirement already satisfied: packaging in c:\users\jusli\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (23.2)
# Requirement already satisfied: psutil in c:\users\jusli\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\jusli\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\jusli\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\jusli\anaconda3\lib\site-packages (from ipykernel->jupyter-dash) (5.14.3)
# Requirement already satisfied: decorator in c:\users\jusli\anaconda3\lib\site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jusli\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.18.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\jusli\anaconda3\lib\site-packages (from ipython->jupyter-dash) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jusli\anaconda3\lib\site-packages (from ipython->jupyter-dash) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\jusli\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: colorama in c:\users\jusli\anaconda3\lib\site-packages (from ipython->jupyter-dash) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jusli\anaconda3\lib\site-packages (from requests->jupyter-dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jusli\anaconda3\lib\site-packages (from requests->jupyter-dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jusli\anaconda3\lib\site-packages (from requests->jupyter-dash) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jusli\anaconda3\lib\site-packages (from requests->jupyter-dash) (2024.7.4)
# Requirement already satisfied: six>=1.7.0 in c:\users\jusli\anaconda3\lib\site-packages (from retrying->jupyter-dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jusli\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jusli\anaconda3\lib\site-packages (from Jinja2>=3.0->flask->jupyter-dash) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jusli\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jusli\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\jusli\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (305.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jusli\anaconda3\lib\site-packages (from plotly>=5.0.0->dash->jupyter-dash) (8.2.2)
# Requirement already satisfied: wcwidth in c:\users\jusli\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\jusli\anaconda3\lib\site-packages (from importlib-metadata->dash->jupyter-dash) (3.17.0)
# Requirement already satisfied: executing in c:\users\jusli\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\jusli\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\jusli\anaconda3\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.2.2)
# Requirement already satisfied: Flask==2.1.0 in c:\users\jusli\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: Werkzeug>=2.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask==2.1.0) (2.0.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask==2.1.0) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask==2.1.0) (2.2.0)
# Requirement already satisfied: click>=8.0 in c:\users\jusli\anaconda3\lib\site-packages (from Flask==2.1.0) (8.1.7)
# Requirement already satisfied: colorama in c:\users\jusli\anaconda3\lib\site-packages (from click>=8.0->Flask==2.1.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jusli\anaconda3\lib\site-packages (from Jinja2>=3.0->Flask==2.1.0) (2.1.3)
# Collecting environ
#   Downloading environ-1.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: environ
#   Building wheel for environ (setup.py): started
#   Building wheel for environ (setup.py): finished with status 'done'
#   Created wheel for environ: filename=environ-1.0-py3-none-any.whl size=3224 sha256=b5d8257b3fb33ff3ece3bf9aaf9e55975d9e1e12197d03a7b25dd04ef983d184
#   Stored in directory: c:\users\jusli\appdata\local\pip\cache\wheels\c0\1d\42\24a13a66646532e4c335df0f5728795d142c6b9cf3b1af8b7b
# Successfully built environ
# Installing collected packages: environ
# Successfully installed environ-1.0

# %%
#!pip install jupyter-server-proxy
# !pip install wget
# Out:
# Requirement already satisfied: wget in c:\users\jusli\anaconda3\lib\site-packages (3.2)

# %%
import wget
import pandas as pd

# %%
import pandas as pd
import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output, State

import plotly.graph_objects as go
import plotly.express as px
from dash import no_update
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[25], line 2
#       1 import pandas as pd
# ----> 2 import dash
#       3 from dash import dcc
#       4 from dash import html
#
# File ~\anaconda3\Lib\site-packages\dash\__init__.py:5
#       1 # pylint: disable=C0413
#       2 # __plotly_dash is for the "make sure you don't have a dash.py" check
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dependencies import (  # noqa: F401,E402
#       6     Input,  # noqa: F401,E402
#       7     Output,  # noqa: F401,E402,
#       8     State,  # noqa: F401,E402
#       9     ClientsideFunction,  # noqa: F401,E402
#      10     MATCH,  # noqa: F401,E402
#      11     ALL,  # noqa: F401,E402
#      12     ALLSMALLER,  # noqa: F401,E402
#      13 )  # noqa: F401,E402
#      14 from . import development  # noqa: F401,E402
#      15 from . import exceptions  # noqa: F401,E402
#
# File ~\anaconda3\Lib\site-packages\dash\dependencies.py:3
#       1 from dash.development.base_component import Component
# ----> 3 from ._validate import validate_callback
#       4 from ._grouping import flatten_grouping, make_grouping_by_index
#       5 from ._utils import stringify_id
#
# File ~\anaconda3\Lib\site-packages\dash\_validate.py:6
#       4 from textwrap import dedent
#       5 from keyword import iskeyword
# ----> 6 import flask
#       8 from ._grouping import grouping_len, map_grouping
#       9 from .development.base_component import Component
#
# File ~\anaconda3\Lib\site-packages\flask\__init__.py:7
#       4 from werkzeug.utils import redirect as redirect
#       6 from . import json as json
# ----> 7 from .app import Flask as Flask
#       8 from .app import Request as Request
#       9 from .app import Response as Response
#
# File ~\anaconda3\Lib\site-packages\flask\app.py:27
#      24 from werkzeug.routing import Rule
#      25 from werkzeug.wrappers import Response as BaseResponse
# ---> 27 from . import cli
#      28 from . import json
#      29 from .config import Config
#
# File ~\anaconda3\Lib\site-packages\flask\cli.py:17
#      14 from werkzeug.utils import import_string
#      16 from .globals import current_app
# ---> 17 from .helpers import get_debug_flag
#      18 from .helpers import get_env
#      19 from .helpers import get_load_dotenv
#
# File ~\anaconda3\Lib\site-packages\flask\helpers.py:14
#      12 import werkzeug.utils
#      13 from werkzeug.routing import BuildError
# ---> 14 from werkzeug.urls import url_quote
#      16 from .globals import _app_ctx_stack
#      17 from .globals import _request_ctx_stack
#
# ImportError: cannot import name 'url_quote' from 'werkzeug.urls' (C:\Users\jusli\anaconda3\Lib\site-packages\werkzeug\urls.py)

# %%
from jupyter_dash.comms import _send_jupyter_config_comm_request
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from jupyter_dash.comms import _send_jupyter_config_comm_request
#
# File ~\anaconda3\Lib\site-packages\jupyter_dash\__init__.py:2
#       1 import jupyter_dash.comms
# ----> 2 from .jupyter_app import JupyterDash
#       3 from .version import __version__
#       5 def _jupyter_nbextension_paths():
#
# File ~\anaconda3\Lib\site-packages\jupyter_dash\jupyter_app.py:1
# ----> 1 import dash
#       2 import os
#       3 import requests
#
# File ~\anaconda3\Lib\site-packages\dash\__init__.py:5
#       1 # pylint: disable=C0413
#       2 # __plotly_dash is for the "make sure you don't have a dash.py" check
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dependencies import (  # noqa: F401,E402
#       6     Input,  # noqa: F401,E402
#       7     Output,  # noqa: F401,E402,
#       8     State,  # noqa: F401,E402
#       9     ClientsideFunction,  # noqa: F401,E402
#      10     MATCH,  # noqa: F401,E402
#      11     ALL,  # noqa: F401,E402
#      12     ALLSMALLER,  # noqa: F401,E402
#      13 )  # noqa: F401,E402
#      14 from . import development  # noqa: F401,E402
#      15 from . import exceptions  # noqa: F401,E402
#
# File ~\anaconda3\Lib\site-packages\dash\dependencies.py:3
#       1 from dash.development.base_component import Component
# ----> 3 from ._validate import validate_callback
#       4 from ._grouping import flatten_grouping, make_grouping_by_index
#       5 from ._utils import stringify_id
#
# File ~\anaconda3\Lib\site-packages\dash\_validate.py:6
#       4 from textwrap import dedent
#       5 from keyword import iskeyword
# ----> 6 import flask
#       8 from ._grouping import grouping_len, map_grouping
#       9 from .development.base_component import Component
#
# File ~\anaconda3\Lib\site-packages\flask\__init__.py:7
#       4 from werkzeug.utils import redirect as redirect
#       6 from . import json as json
# ----> 7 from .app import Flask as Flask
#       8 from .app import Request as Request
#       9 from .app import Response as Response
#
# File ~\anaconda3\Lib\site-packages\flask\app.py:27
#      24 from werkzeug.routing import Rule
#      25 from werkzeug.wrappers import Response as BaseResponse
# ---> 27 from . import cli
#      28 from . import json
#      29 from .config import Config
#
# File ~\anaconda3\Lib\site-packages\flask\cli.py:17
#      14 from werkzeug.utils import import_string
#      16 from .globals import current_app
# ---> 17 from .helpers import get_debug_flag
#      18 from .helpers import get_env
#      19 from .helpers import get_load_dotenv
#
# File ~\anaconda3\Lib\site-packages\flask\helpers.py:14
#      12 import werkzeug.utils
#      13 from werkzeug.routing import BuildError
# ---> 14 from werkzeug.urls import url_quote
#      16 from .globals import _app_ctx_stack
#      17 from .globals import _request_ctx_stack
#
# ImportError: cannot import name 'url_quote' from 'werkzeug.urls' (C:\Users\jusli\anaconda3\Lib\site-packages\werkzeug\urls.py)

# %%
from jupyter_dash import JupyterDash
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 from jupyter_dash import JupyterDash
#
# File ~\anaconda3\Lib\site-packages\jupyter_dash\__init__.py:2
#       1 import jupyter_dash.comms
# ----> 2 from .jupyter_app import JupyterDash
#       3 from .version import __version__
#       5 def _jupyter_nbextension_paths():
#
# File ~\anaconda3\Lib\site-packages\jupyter_dash\jupyter_app.py:1
# ----> 1 import dash
#       2 import os
#       3 import requests
#
# File ~\anaconda3\Lib\site-packages\dash\__init__.py:5
#       1 # pylint: disable=C0413
#       2 # __plotly_dash is for the "make sure you don't have a dash.py" check
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dependencies import (  # noqa: F401,E402
#       6     Input,  # noqa: F401,E402
#       7     Output,  # noqa: F401,E402,
#       8     State,  # noqa: F401,E402
#       9     ClientsideFunction,  # noqa: F401,E402
#      10     MATCH,  # noqa: F401,E402
#      11     ALL,  # noqa: F401,E402
#      12     ALLSMALLER,  # noqa: F401,E402
#      13 )  # noqa: F401,E402
#      14 from . import development  # noqa: F401,E402
#      15 from . import exceptions  # noqa: F401,E402
#
# File ~\anaconda3\Lib\site-packages\dash\dependencies.py:3
#       1 from dash.development.base_component import Component
# ----> 3 from ._validate import validate_callback
#       4 from ._grouping import flatten_grouping, make_grouping_by_index
#       5 from ._utils import stringify_id
#
# File ~\anaconda3\Lib\site-packages\dash\_validate.py:6
#       4 from textwrap import dedent
#       5 from keyword import iskeyword
# ----> 6 import flask
#       8 from ._grouping import grouping_len, map_grouping
#       9 from .development.base_component import Component
#
# File ~\anaconda3\Lib\site-packages\flask\__init__.py:7
#       4 from werkzeug.utils import redirect as redirect
#       6 from . import json as json
# ----> 7 from .app import Flask as Flask
#       8 from .app import Request as Request
#       9 from .app import Response as Response
#
# File ~\anaconda3\Lib\site-packages\flask\app.py:27
#      24 from werkzeug.routing import Rule
#      25 from werkzeug.wrappers import Response as BaseResponse
# ---> 27 from . import cli
#      28 from . import json
#      29 from .config import Config
#
# File ~\anaconda3\Lib\site-packages\flask\cli.py:17
#      14 from werkzeug.utils import import_string
#      16 from .globals import current_app
# ---> 17 from .helpers import get_debug_flag
#      18 from .helpers import get_env
#      19 from .helpers import get_load_dotenv
#
# File ~\anaconda3\Lib\site-packages\flask\helpers.py:14
#      12 import werkzeug.utils
#      13 from werkzeug.routing import BuildError
# ---> 14 from werkzeug.urls import url_quote
#      16 from .globals import _app_ctx_stack
#      17 from .globals import _request_ctx_stack
#
# ImportError: cannot import name 'url_quote' from 'werkzeug.urls' (C:\Users\jusli\anaconda3\Lib\site-packages\werkzeug\urls.py)

# %%
# !wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
